# %% [markdown]
# <a href="https://colab.research.google.com/github/PetrovES570/PDA_SOL/blob/main/Practic_1_PetrovES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа 1. Начало работы с API

# %% [markdown]
# # **Вариант 16.** География разработчиков: Изучение географического распределения разработчиков.

# %% [markdown]
# # 1.2. GitHub API

# %% [markdown]
# **1.2.1.** Сгенерировать персональный токен на 7 дней на странице https://github.com/settings/tokens/new
#
# ![](https://drive.google.com/uc?export=view&id=1rNV_0jXbY4GLYAlFu-SUbOoGYWk9hKGe)

# %% [markdown]
# **1.2.2.**	Настройка окружения: убедитесь, что у вас установлены необходимые библиотеки: requests, pandas, matplotlib, seaborn.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1.2.3.** Подключение к GitHub API

# %%
GITHUB_API_URL = "https://api.github.com"
ACCESS_TOKEN = "токен"
headers = {
    "Authorization": f"token {ACCESS_TOKEN}"
}

# %% [markdown]
# > Токен был удален, в соответствии с требованиями безопасности.

# %% [markdown]
# **1.2.4.** Проанализировать собственные репозитории.
#
#  Чтобы вывести список всех репозиториев пользователя с GitHub и отсортировать их по дате создания с помощью Python, можно воспользоваться библиотекой requests для взаимодействия с GitHub API.

# %%
import requests

def get_repositories(username):
    url = f"https://api.github.com/users/{username}/repos"
    response = requests.get(url)

    if response.status_code == 200:
        repos = response.json()
        # Сортируем репозитории по дате создания
        sorted_repos = sorted(repos, key=lambda x: x['created_at'], reverse=True)
        for repo in sorted_repos:
            print(f"Repository: {repo['name']}, Created at: {repo['created_at']}")
    else:
        print(f"Error: Unable to fetch repositories for user {username} (Status code: {response.status_code})")

get_repositories('PetrovES570')
# Out:
# Repository: PDA_SOL, Created at: 2023-09-12T16:20:13Z

# %% [markdown]
# **1.2.5.**	Получение данных о репозиториях. Получить информацию о репозиториях, используя определенный поисковый запрос, например, **География разработчиков**. Изучение географического распределения
# разработчиков.

# %%
query = "developer country"
response = requests.get(f"{GITHUB_API_URL}/search/repositories", params={"q": query}, headers=headers)
data = response.json()
repos = data['items']
repos
# Out:
# [{'id': 102975784,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDI5NzU3ODQ=',
#   'name': 'CountryList',
#   'full_name': 'juanpablofernandez/CountryList',
#   'private': False,
#   'owner': {'login': 'juanpablofernandez',
#    'id': 20647505,
#    'node_id': 'MDQ6VXNlcjIwNjQ3NTA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20647505?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juanpablofernandez',
#    'html_url': 'https://github.com/juanpablofernandez',
#    'followers_url': 'https://api.github.com/users/juanpablofernandez/followers',
#    'following_url': 'https://api.github.com/users/juanpablofernandez/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/juanpablofernandez/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/juanpablofernandez/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/juanpablofernandez/subscriptions',
#    'organizations_url': 'https://api.github.com/users/juanpablofernandez/orgs',
#    'repos_url': 'https://api.github.com/users/juanpablofernandez/repos',
#    'events_url': 'https://api.github.com/users/juanpablofernandez/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/juanpablofernandez/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/juanpablofernandez/CountryList',
#   'description': 'An iOS Framework that allows developers to present the user with a list of Countries and their respective information, like country code, phone extension and flag.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/juanpablofernandez/CountryList',
#   'forks_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/forks',
#   'keys_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/teams',
#   'hooks_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/hooks',
#   'issue_events_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/events',
#   'assignees_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/tags',
#   'blobs_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/languages',
#   'stargazers_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/stargazers',
#   'contributors_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/contributors',
#   'subscribers_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/subscribers',
#   'subscription_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/subscription',
#   'commits_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/merges',
#   'archive_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/downloads',
#   'issues_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/juanpablofernandez/CountryList/deployments',
#   'created_at': '2017-09-09T18:17:51Z',
#   'updated_at': '2023-03-29T13:26:34Z',
#   'pushed_at': '2019-03-20T09:14:15Z',
#   'git_url': 'git://github.com/juanpablofernandez/CountryList.git',
#   'ssh_url': 'git@github.com:juanpablofernandez/CountryList.git',
#   'clone_url': 'https://github.com/juanpablofernandez/CountryList.git',
#   'svn_url': 'https://github.com/juanpablofernandez/CountryList',
#   'homepage': '',
#   'size': 3575,
#   'stargazers_count': 38,
#   'watchers_count': 38,
#   'language': 'Swift',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 36,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 9,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['cocoapods',
#    'country-codes',
#    'country-flags',
#    'country-list',
#    'country-picker',
#    'extensions',
#    'framework',
#    'ios',
#    'phone-format',
#    'phone-number',
#    'swift',
#    'swifty'],
#   'visibility': 'public',
#   'forks': 36,
#   'open_issues': 9,
#   'watchers': 38,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 99779240,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5OTc3OTI0MA==',
#   'name': 'MRSelectCountry',
#   'full_name': 'mrazam110/MRSelectCountry',
#   'private': False,
#   'owner': {'login': 'mrazam110',
#    'id': 5674070,
#    'node_id': 'MDQ6VXNlcjU2NzQwNzA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5674070?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mrazam110',
#    'html_url': 'https://github.com/mrazam110',
#    'followers_url': 'https://api.github.com/users/mrazam110/followers',
#    'following_url': 'https://api.github.com/users/mrazam110/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mrazam110/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mrazam110/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mrazam110/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mrazam110/orgs',
#    'repos_url': 'https://api.github.com/users/mrazam110/repos',
#    'events_url': 'https://api.github.com/users/mrazam110/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mrazam110/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mrazam110/MRSelectCountry',
#   'description': 'An easy way to get country data which includes the country name and dial code for iOS Developers',
#   'fork': False,
#   'url': 'https://api.github.com/repos/mrazam110/MRSelectCountry',
#   'forks_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/forks',
#   'keys_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/teams',
#   'hooks_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/events',
#   'assignees_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/tags',
#   'blobs_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/languages',
#   'stargazers_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/subscription',
#   'commits_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/merges',
#   'archive_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/downloads',
#   'issues_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mrazam110/MRSelectCountry/deployments',
#   'created_at': '2017-08-09T07:38:00Z',
#   'updated_at': '2021-09-17T05:51:52Z',
#   'pushed_at': '2018-10-26T13:26:01Z',
#   'git_url': 'git://github.com/mrazam110/MRSelectCountry.git',
#   'ssh_url': 'git@github.com:mrazam110/MRSelectCountry.git',
#   'clone_url': 'https://github.com/mrazam110/MRSelectCountry.git',
#   'svn_url': 'https://github.com/mrazam110/MRSelectCountry',
#   'homepage': '',
#   'size': 312,
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': 'Swift',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 4,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['cocoapods', 'ios', 'ios-swift', 'swift'],
#   'visibility': 'public',
#   'forks': 4,
#   'open_issues': 1,
#   'watchers': 15,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 134281439,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzQyODE0Mzk=',
#   'name': 'HighCountryAngular',
#   'full_name': 'ngHighCountry/HighCountryAngular',
#   'private': False,
#   'owner': {'login': 'ngHighCountry',
#    'id': 39127745,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5MTI3NzQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39127745?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ngHighCountry',
#    'html_url': 'https://github.com/ngHighCountry',
#    'followers_url': 'https://api.github.com/users/ngHighCountry/followers',
#    'following_url': 'https://api.github.com/users/ngHighCountry/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ngHighCountry/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ngHighCountry/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ngHighCountry/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ngHighCountry/orgs',
#    'repos_url': 'https://api.github.com/users/ngHighCountry/repos',
#    'events_url': 'https://api.github.com/users/ngHighCountry/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ngHighCountry/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/ngHighCountry/HighCountryAngular',
#   'description': 'High Country Angular is a group of tech enthusiasts, web designers, software developers and engineers, gathering together on a regular basis to share knowledge, ideas, and lessons learned in working with the Angular framework.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular',
#   'forks_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/forks',
#   'keys_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/teams',
#   'hooks_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/hooks',
#   'issue_events_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/events',
#   'assignees_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/tags',
#   'blobs_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/languages',
#   'stargazers_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/stargazers',
#   'contributors_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/contributors',
#   'subscribers_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/subscription',
#   'commits_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/merges',
#   'archive_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/downloads',
#   'issues_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/ngHighCountry/HighCountryAngular/deployments',
#   'created_at': '2018-05-21T14:36:58Z',
#   'updated_at': '2023-01-28T06:51:16Z',
#   'pushed_at': '2020-09-03T23:21:09Z',
#   'git_url': 'git://github.com/ngHighCountry/HighCountryAngular.git',
#   'ssh_url': 'git@github.com:ngHighCountry/HighCountryAngular.git',
#   'clone_url': 'https://github.com/ngHighCountry/HighCountryAngular.git',
#   'svn_url': 'https://github.com/ngHighCountry/HighCountryAngular',
#   'homepage': None,
#   'size': 44830,
#   'stargazers_count': 5,
#   'watchers_count': 5,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 9,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 9,
#   'open_issues': 3,
#   'watchers': 5,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 29499566,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTQ5OTU2Ng==',
#   'name': 'country-master',
#   'full_name': 'uglymittens/country-master',
#   'private': False,
#   'owner': {'login': 'uglymittens',
#    'id': 1050711,
#    'node_id': 'MDQ6VXNlcjEwNTA3MTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1050711?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/uglymittens',
#    'html_url': 'https://github.com/uglymittens',
#    'followers_url': 'https://api.github.com/users/uglymittens/followers',
#    'following_url': 'https://api.github.com/users/uglymittens/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/uglymittens/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/uglymittens/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/uglymittens/subscriptions',
#    'organizations_url': 'https://api.github.com/users/uglymittens/orgs',
#    'repos_url': 'https://api.github.com/users/uglymittens/repos',
#    'events_url': 'https://api.github.com/users/uglymittens/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/uglymittens/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/uglymittens/country-master',
#   'description': "Android Library project which helps developers work with country iso codes and country telephone prefixes and more! Uses Google's libphonenumber library",
#   'fork': False,
#   'url': 'https://api.github.com/repos/uglymittens/country-master',
#   'forks_url': 'https://api.github.com/repos/uglymittens/country-master/forks',
#   'keys_url': 'https://api.github.com/repos/uglymittens/country-master/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/uglymittens/country-master/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/uglymittens/country-master/teams',
#   'hooks_url': 'https://api.github.com/repos/uglymittens/country-master/hooks',
#   'issue_events_url': 'https://api.github.com/repos/uglymittens/country-master/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/uglymittens/country-master/events',
#   'assignees_url': 'https://api.github.com/repos/uglymittens/country-master/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/uglymittens/country-master/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/uglymittens/country-master/tags',
#   'blobs_url': 'https://api.github.com/repos/uglymittens/country-master/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/uglymittens/country-master/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/uglymittens/country-master/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/uglymittens/country-master/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/uglymittens/country-master/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/uglymittens/country-master/languages',
#   'stargazers_url': 'https://api.github.com/repos/uglymittens/country-master/stargazers',
#   'contributors_url': 'https://api.github.com/repos/uglymittens/country-master/contributors',
#   'subscribers_url': 'https://api.github.com/repos/uglymittens/country-master/subscribers',
#   'subscription_url': 'https://api.github.com/repos/uglymittens/country-master/subscription',
#   'commits_url': 'https://api.github.com/repos/uglymittens/country-master/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/uglymittens/country-master/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/uglymittens/country-master/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/uglymittens/country-master/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/uglymittens/country-master/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/uglymittens/country-master/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/uglymittens/country-master/merges',
#   'archive_url': 'https://api.github.com/repos/uglymittens/country-master/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/uglymittens/country-master/downloads',
#   'issues_url': 'https://api.github.com/repos/uglymittens/country-master/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/uglymittens/country-master/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/uglymittens/country-master/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/uglymittens/country-master/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/uglymittens/country-master/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/uglymittens/country-master/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/uglymittens/country-master/deployments',
#   'created_at': '2015-01-19T22:20:53Z',
#   'updated_at': '2022-02-12T14:10:34Z',
#   'pushed_at': '2015-04-22T06:25:06Z',
#   'git_url': 'git://github.com/uglymittens/country-master.git',
#   'ssh_url': 'git@github.com:uglymittens/country-master.git',
#   'clone_url': 'https://github.com/uglymittens/country-master.git',
#   'svn_url': 'https://github.com/uglymittens/country-master',
#   'homepage': '',
#   'size': 608,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 4,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 4,
#   'open_issues': 3,
#   'watchers': 11,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 237456607,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzc0NTY2MDc=',
#   'name': 'radicle-decisions',
#   'full_name': 'radicle-dev/radicle-decisions',
#   'private': False,
#   'owner': {'login': 'radicle-dev',
#    'id': 48290027,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ4MjkwMDI3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48290027?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/radicle-dev',
#    'html_url': 'https://github.com/radicle-dev',
#    'followers_url': 'https://api.github.com/users/radicle-dev/followers',
#    'following_url': 'https://api.github.com/users/radicle-dev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/radicle-dev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/radicle-dev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/radicle-dev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/radicle-dev/orgs',
#    'repos_url': 'https://api.github.com/users/radicle-dev/repos',
#    'events_url': 'https://api.github.com/users/radicle-dev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/radicle-dev/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/radicle-dev/radicle-decisions',
#   'description': 'Radicle Developers of All Countries, Unite!',
#   'fork': False,
#   'url': 'https://api.github.com/repos/radicle-dev/radicle-decisions',
#   'forks_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/forks',
#   'keys_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/teams',
#   'hooks_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/hooks',
#   'issue_events_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/events',
#   'assignees_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/tags',
#   'blobs_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/languages',
#   'stargazers_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/stargazers',
#   'contributors_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/contributors',
#   'subscribers_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/subscribers',
#   'subscription_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/subscription',
#   'commits_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/merges',
#   'archive_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/downloads',
#   'issues_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/radicle-dev/radicle-decisions/deployments',
#   'created_at': '2020-01-31T15:20:55Z',
#   'updated_at': '2021-07-20T17:14:28Z',
#   'pushed_at': '2021-04-06T14:40:10Z',
#   'git_url': 'git://github.com/radicle-dev/radicle-decisions.git',
#   'ssh_url': 'git@github.com:radicle-dev/radicle-decisions.git',
#   'clone_url': 'https://github.com/radicle-dev/radicle-decisions.git',
#   'svn_url': 'https://github.com/radicle-dev/radicle-decisions',
#   'homepage': None,
#   'size': 32,
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'Shell',
#   'has_issues': False,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 2,
#   'watchers': 17,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 585899085,
#   'node_id': 'R_kgDOIuwcTQ',
#   'name': 'malawi-country-data',
#   'full_name': 'PreciousNyasulu/malawi-country-data',
#   'private': False,
#   'owner': {'login': 'PreciousNyasulu',
#    'id': 62704803,
#    'node_id': 'MDQ6VXNlcjYyNzA0ODAz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62704803?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PreciousNyasulu',
#    'html_url': 'https://github.com/PreciousNyasulu',
#    'followers_url': 'https://api.github.com/users/PreciousNyasulu/followers',
#    'following_url': 'https://api.github.com/users/PreciousNyasulu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PreciousNyasulu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PreciousNyasulu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PreciousNyasulu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PreciousNyasulu/orgs',
#    'repos_url': 'https://api.github.com/users/PreciousNyasulu/repos',
#    'events_url': 'https://api.github.com/users/PreciousNyasulu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PreciousNyasulu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/PreciousNyasulu/malawi-country-data',
#   'description': "With this API, developers can easily access and retrieve data related to these administrative divisions, enabling them to build location-based applications, conduct geospatial analysis, or enhance existing systems with accurate and up-to-date information about Malawi's geographic structure.",
#   'fork': False,
#   'url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data',
#   'forks_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/forks',
#   'keys_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/teams',
#   'hooks_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/hooks',
#   'issue_events_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/events',
#   'assignees_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/tags',
#   'blobs_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/languages',
#   'stargazers_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/stargazers',
#   'contributors_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/contributors',
#   'subscribers_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/subscribers',
#   'subscription_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/subscription',
#   'commits_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/merges',
#   'archive_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/downloads',
#   'issues_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/PreciousNyasulu/malawi-country-data/deployments',
#   'created_at': '2023-01-06T11:40:39Z',
#   'updated_at': '2024-08-16T08:41:48Z',
#   'pushed_at': '2023-11-29T22:24:43Z',
#   'git_url': 'git://github.com/PreciousNyasulu/malawi-country-data.git',
#   'ssh_url': 'git@github.com:PreciousNyasulu/malawi-country-data.git',
#   'clone_url': 'https://github.com/PreciousNyasulu/malawi-country-data.git',
#   'svn_url': 'https://github.com/PreciousNyasulu/malawi-country-data',
#   'homepage': 'https://malawi-country-data.fly.dev/docs/index.html',
#   'size': 184,
#   'stargazers_count': 12,
#   'watchers_count': 12,
#   'language': 'Go',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['api', 'country-data', 'country-information', 'malawi'],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 1,
#   'watchers': 12,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 60624109,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MDYyNDEwOQ==',
#   'name': 'locator',
#   'full_name': 'olotintemitope/locator',
#   'private': False,
#   'owner': {'login': 'olotintemitope',
#    'id': 14159435,
#    'node_id': 'MDQ6VXNlcjE0MTU5NDM1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14159435?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/olotintemitope',
#    'html_url': 'https://github.com/olotintemitope',
#    'followers_url': 'https://api.github.com/users/olotintemitope/followers',
#    'following_url': 'https://api.github.com/users/olotintemitope/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/olotintemitope/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/olotintemitope/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/olotintemitope/subscriptions',
#    'organizations_url': 'https://api.github.com/users/olotintemitope/orgs',
#    'repos_url': 'https://api.github.com/users/olotintemitope/repos',
#    'events_url': 'https://api.github.com/users/olotintemitope/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/olotintemitope/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/olotintemitope/locator',
#   'description': 'This Package provides an API where  developers around the world can access various information about countries, states and counties.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/olotintemitope/locator',
#   'forks_url': 'https://api.github.com/repos/olotintemitope/locator/forks',
#   'keys_url': 'https://api.github.com/repos/olotintemitope/locator/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/olotintemitope/locator/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/olotintemitope/locator/teams',
#   'hooks_url': 'https://api.github.com/repos/olotintemitope/locator/hooks',
#   'issue_events_url': 'https://api.github.com/repos/olotintemitope/locator/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/olotintemitope/locator/events',
#   'assignees_url': 'https://api.github.com/repos/olotintemitope/locator/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/olotintemitope/locator/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/olotintemitope/locator/tags',
#   'blobs_url': 'https://api.github.com/repos/olotintemitope/locator/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/olotintemitope/locator/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/olotintemitope/locator/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/olotintemitope/locator/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/olotintemitope/locator/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/olotintemitope/locator/languages',
#   'stargazers_url': 'https://api.github.com/repos/olotintemitope/locator/stargazers',
#   'contributors_url': 'https://api.github.com/repos/olotintemitope/locator/contributors',
#   'subscribers_url': 'https://api.github.com/repos/olotintemitope/locator/subscribers',
#   'subscription_url': 'https://api.github.com/repos/olotintemitope/locator/subscription',
#   'commits_url': 'https://api.github.com/repos/olotintemitope/locator/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/olotintemitope/locator/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/olotintemitope/locator/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/olotintemitope/locator/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/olotintemitope/locator/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/olotintemitope/locator/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/olotintemitope/locator/merges',
#   'archive_url': 'https://api.github.com/repos/olotintemitope/locator/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/olotintemitope/locator/downloads',
#   'issues_url': 'https://api.github.com/repos/olotintemitope/locator/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/olotintemitope/locator/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/olotintemitope/locator/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/olotintemitope/locator/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/olotintemitope/locator/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/olotintemitope/locator/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/olotintemitope/locator/deployments',
#   'created_at': '2016-06-07T15:19:06Z',
#   'updated_at': '2023-01-28T14:32:15Z',
#   'pushed_at': '2020-05-16T11:51:07Z',
#   'git_url': 'git://github.com/olotintemitope/locator.git',
#   'ssh_url': 'git@github.com:olotintemitope/locator.git',
#   'clone_url': 'https://github.com/olotintemitope/locator.git',
#   'svn_url': 'https://github.com/olotintemitope/locator',
#   'homepage': '',
#   'size': 117,
#   'stargazers_count': 19,
#   'watchers_count': 19,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 9,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 9,
#   'open_issues': 3,
#   'watchers': 19,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 76396480,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3NjM5NjQ4MA==',
#   'name': 'MWLI',
#   'full_name': 'balkanfoss/MWLI',
#   'private': False,
#   'owner': {'login': 'balkanfoss',
#    'id': 24553731,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI0NTUzNzMx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24553731?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/balkanfoss',
#    'html_url': 'https://github.com/balkanfoss',
#    'followers_url': 'https://api.github.com/users/balkanfoss/followers',
#    'following_url': 'https://api.github.com/users/balkanfoss/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/balkanfoss/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/balkanfoss/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/balkanfoss/subscriptions',
#    'organizations_url': 'https://api.github.com/users/balkanfoss/orgs',
#    'repos_url': 'https://api.github.com/users/balkanfoss/repos',
#    'events_url': 'https://api.github.com/users/balkanfoss/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/balkanfoss/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/balkanfoss/MWLI',
#   'description': 'A label for developers to add to their sites, so they can promote themselves and their country.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/balkanfoss/MWLI',
#   'forks_url': 'https://api.github.com/repos/balkanfoss/MWLI/forks',
#   'keys_url': 'https://api.github.com/repos/balkanfoss/MWLI/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/balkanfoss/MWLI/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/balkanfoss/MWLI/teams',
#   'hooks_url': 'https://api.github.com/repos/balkanfoss/MWLI/hooks',
#   'issue_events_url': 'https://api.github.com/repos/balkanfoss/MWLI/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/balkanfoss/MWLI/events',
#   'assignees_url': 'https://api.github.com/repos/balkanfoss/MWLI/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/balkanfoss/MWLI/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/balkanfoss/MWLI/tags',
#   'blobs_url': 'https://api.github.com/repos/balkanfoss/MWLI/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/balkanfoss/MWLI/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/balkanfoss/MWLI/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/balkanfoss/MWLI/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/balkanfoss/MWLI/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/balkanfoss/MWLI/languages',
#   'stargazers_url': 'https://api.github.com/repos/balkanfoss/MWLI/stargazers',
#   'contributors_url': 'https://api.github.com/repos/balkanfoss/MWLI/contributors',
#   'subscribers_url': 'https://api.github.com/repos/balkanfoss/MWLI/subscribers',
#   'subscription_url': 'https://api.github.com/repos/balkanfoss/MWLI/subscription',
#   'commits_url': 'https://api.github.com/repos/balkanfoss/MWLI/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/balkanfoss/MWLI/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/balkanfoss/MWLI/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/balkanfoss/MWLI/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/balkanfoss/MWLI/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/balkanfoss/MWLI/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/balkanfoss/MWLI/merges',
#   'archive_url': 'https://api.github.com/repos/balkanfoss/MWLI/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/balkanfoss/MWLI/downloads',
#   'issues_url': 'https://api.github.com/repos/balkanfoss/MWLI/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/balkanfoss/MWLI/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/balkanfoss/MWLI/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/balkanfoss/MWLI/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/balkanfoss/MWLI/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/balkanfoss/MWLI/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/balkanfoss/MWLI/deployments',
#   'created_at': '2016-12-13T20:39:05Z',
#   'updated_at': '2021-05-22T15:07:18Z',
# ...
#   'events_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/events',
#   'assignees_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/tags',
#   'blobs_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/languages',
#   'stargazers_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/subscription',
#   'commits_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/merges',
#   'archive_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/downloads',
#   'issues_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Mohammed20201991/Streamlit_Web_App_ML2022/deployments',
#   'created_at': '2022-06-21T18:07:13Z',
#   'updated_at': '2023-09-18T19:14:08Z',
#   'pushed_at': '2022-06-29T12:19:01Z',
#   'git_url': 'git://github.com/Mohammed20201991/Streamlit_Web_App_ML2022.git',
#   'ssh_url': 'git@github.com:Mohammed20201991/Streamlit_Web_App_ML2022.git',
#   'clone_url': 'https://github.com/Mohammed20201991/Streamlit_Web_App_ML2022.git',
#   'svn_url': 'https://github.com/Mohammed20201991/Streamlit_Web_App_ML2022',
#   'homepage': None,
#   'size': 8720,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 411853026,
#   'node_id': 'R_kgDOGIxg4g',
#   'name': 'country-quiz',
#   'full_name': 'danielpaz98/country-quiz',
#   'private': False,
#   'owner': {'login': 'danielpaz98',
#    'id': 23371045,
#    'node_id': 'MDQ6VXNlcjIzMzcxMDQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23371045?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danielpaz98',
#    'html_url': 'https://github.com/danielpaz98',
#    'followers_url': 'https://api.github.com/users/danielpaz98/followers',
#    'following_url': 'https://api.github.com/users/danielpaz98/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/danielpaz98/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/danielpaz98/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/danielpaz98/subscriptions',
#    'organizations_url': 'https://api.github.com/users/danielpaz98/orgs',
#    'repos_url': 'https://api.github.com/users/danielpaz98/repos',
#    'events_url': 'https://api.github.com/users/danielpaz98/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/danielpaz98/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/danielpaz98/country-quiz',
#   'description': 'DevChallenge - Front-end Developer #6 Country quiz',
#   'fork': False,
#   'url': 'https://api.github.com/repos/danielpaz98/country-quiz',
#   'forks_url': 'https://api.github.com/repos/danielpaz98/country-quiz/forks',
#   'keys_url': 'https://api.github.com/repos/danielpaz98/country-quiz/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/danielpaz98/country-quiz/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/danielpaz98/country-quiz/teams',
#   'hooks_url': 'https://api.github.com/repos/danielpaz98/country-quiz/hooks',
#   'issue_events_url': 'https://api.github.com/repos/danielpaz98/country-quiz/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/danielpaz98/country-quiz/events',
#   'assignees_url': 'https://api.github.com/repos/danielpaz98/country-quiz/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/danielpaz98/country-quiz/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/danielpaz98/country-quiz/tags',
#   'blobs_url': 'https://api.github.com/repos/danielpaz98/country-quiz/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/danielpaz98/country-quiz/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/danielpaz98/country-quiz/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/danielpaz98/country-quiz/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/danielpaz98/country-quiz/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/danielpaz98/country-quiz/languages',
#   'stargazers_url': 'https://api.github.com/repos/danielpaz98/country-quiz/stargazers',
#   'contributors_url': 'https://api.github.com/repos/danielpaz98/country-quiz/contributors',
#   'subscribers_url': 'https://api.github.com/repos/danielpaz98/country-quiz/subscribers',
#   'subscription_url': 'https://api.github.com/repos/danielpaz98/country-quiz/subscription',
#   'commits_url': 'https://api.github.com/repos/danielpaz98/country-quiz/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/danielpaz98/country-quiz/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/danielpaz98/country-quiz/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/danielpaz98/country-quiz/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/danielpaz98/country-quiz/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/danielpaz98/country-quiz/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/danielpaz98/country-quiz/merges',
#   'archive_url': 'https://api.github.com/repos/danielpaz98/country-quiz/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/danielpaz98/country-quiz/downloads',
#   'issues_url': 'https://api.github.com/repos/danielpaz98/country-quiz/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/danielpaz98/country-quiz/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/danielpaz98/country-quiz/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/danielpaz98/country-quiz/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/danielpaz98/country-quiz/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/danielpaz98/country-quiz/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/danielpaz98/country-quiz/deployments',
#   'created_at': '2021-09-29T23:00:26Z',
#   'updated_at': '2023-03-07T09:18:29Z',
#   'pushed_at': '2021-10-06T06:32:40Z',
#   'git_url': 'git://github.com/danielpaz98/country-quiz.git',
#   'ssh_url': 'git@github.com:danielpaz98/country-quiz.git',
#   'clone_url': 'https://github.com/danielpaz98/country-quiz.git',
#   'svn_url': 'https://github.com/danielpaz98/country-quiz',
#   'homepage': 'https://country-quiz-danielpaz98.vercel.app',
#   'size': 183,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Vue',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['css', 'html', 'javascript', 'vitejs', 'vuejs'],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 127923355,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjc5MjMzNTU=',
#   'name': 'I_am_Korean',
#   'full_name': 'smallerhand/I_am_Korean',
#   'private': False,
#   'owner': {'login': 'smallerhand',
#    'id': 33567817,
#    'node_id': 'MDQ6VXNlcjMzNTY3ODE3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33567817?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smallerhand',
#    'html_url': 'https://github.com/smallerhand',
#    'followers_url': 'https://api.github.com/users/smallerhand/followers',
#    'following_url': 'https://api.github.com/users/smallerhand/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/smallerhand/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/smallerhand/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/smallerhand/subscriptions',
#    'organizations_url': 'https://api.github.com/users/smallerhand/orgs',
#    'repos_url': 'https://api.github.com/users/smallerhand/repos',
#    'events_url': 'https://api.github.com/users/smallerhand/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/smallerhand/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/smallerhand/I_am_Korean',
#   'description': 'I want to make some developer friends in another country.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/smallerhand/I_am_Korean',
#   'forks_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/forks',
#   'keys_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/teams',
#   'hooks_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/hooks',
#   'issue_events_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/events',
#   'assignees_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/tags',
#   'blobs_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/languages',
#   'stargazers_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/stargazers',
#   'contributors_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/contributors',
#   'subscribers_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/subscribers',
#   'subscription_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/subscription',
#   'commits_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/merges',
#   'archive_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/downloads',
#   'issues_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/smallerhand/I_am_Korean/deployments',
#   'created_at': '2018-04-03T14:45:17Z',
#   'updated_at': '2018-04-04T02:12:16Z',
#   'pushed_at': '2018-04-03T15:11:46Z',
#   'git_url': 'git://github.com/smallerhand/I_am_Korean.git',
#   'ssh_url': 'git@github.com:smallerhand/I_am_Korean.git',
#   'clone_url': 'https://github.com/smallerhand/I_am_Korean.git',
#   'svn_url': 'https://github.com/smallerhand/I_am_Korean',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0}]

# %% [markdown]
# **1.2.6** Анализ данных. Извлеките и проанализируйте данные, такие как количество звезд, форков, количество открытых issues и т.д.

# %%
repo_data = pd.DataFrame(repos, columns=['name', 'stargazers_count', 'forks_count', 'open_issues_count', 'size'])
print(repo_data.describe())
# Out:
#        stargazers_count  forks_count  open_issues_count          size
# count         30.000000    30.000000          30.000000     30.000000
# mean           6.566667     3.233333           1.000000   4067.866667
# std            8.426900     7.238229           1.947589   9308.967407
# min            0.000000     0.000000           0.000000      1.000000
# 25%            1.250000     0.000000           0.000000    183.250000
# 50%            3.000000     0.000000           0.000000    434.500000
# 75%           10.250000     3.750000           1.000000   2806.750000
# max           38.000000    36.000000           9.000000  44830.000000

# %% [markdown]
# **1.2.6.** Визуализация данных: постройте графики для визуализации активности репозиториев.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", context="talk")
plt.figure(figsize=(12, 7))

sns.barplot(x='name', y='stargazers_count', data=repo_data.head(10), color="skyblue")

for index, row in repo_data.head(10).iterrows():
    plt.text(index, row['stargazers_count'] + 1, round(row['stargazers_count'], 2),
             color='black', ha="center", fontsize=12, fontweight='bold')

plt.xticks(rotation=45, ha='right', fontsize=9, fontweight='bold')
plt.yticks(fontsize=12)
plt.title('Top 10 repositories', fontsize=16, fontweight='bold')
plt.xlabel('Name repositories', fontsize=16, fontweight='bold')
plt.ylabel('Sum star', fontsize=16, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='name', y='forks_count', data=repo_data.head(10), color="blue")

for i in range(10):
    plt.text(i, repo_data['forks_count'].iloc[i] + 5,
             repo_data['forks_count'].iloc[i],
             ha='center', va='bottom', fontsize=9)

plt.title('Top 10 repositories on fork', fontsize=16, fontweight='bold')
plt.xlabel('Name repositories', fontsize=12)
plt.ylabel('Sum fork', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Задание:**  Проанализируйте активность пользователей, например, по количеству коммитов или участия в pull requests.

# %%
repo_name = repos[0]['full_name']
commit_response = requests.get(f"{GITHUB_API_URL}/repos/{repo_name}/commits", headers=headers)
commits = commit_response.json()
print(f"Количество коммитов в репе {repo_name}: {len(commits)}")
# Out:
# Количество коммитов в репе juanpablofernandez/CountryList: 9

# %%
repo_name = 'CountryDeveloper'
commit_response = requests.get(f"{GITHUB_API_URL}/repos/{repo_name}/commits", headers=headers)
commits = commit_response.json()
print(f"Количество коммитов в репе {repo_name}: {len(commits)}")
# Out:
# Количество коммитов в репе CountryDeveloper: 3

# %%
repo_name = repos[0]['full_name']

open_pr_response = requests.get(f"{GITHUB_API_URL}/repos/{repo_name}/pulls?state=open", headers=headers)
open_prs = open_pr_response.json()
num_open_prs = len(open_prs)
print(f"Кол-во открытых пулл реквестов в репозитории {repo_name}: {num_open_prs}")

closed_pr_response = requests.get(f"{GITHUB_API_URL}/repos/{repo_name}/pulls?state=closed", headers=headers)
closed_prs = closed_pr_response.json()
num_closed_prs = len(closed_prs)
print(f"Кол-во открытых пулл реквестов в репозитории {repo_name}: {num_closed_prs}")
# Out:
# Кол-во открытых пулл реквестов в репозитории juanpablofernandez/CountryList: 3
# Кол-во открытых пулл реквестов в репозитории juanpablofernandez/CountryList: 1

# %%
repo_name = 'CountryDeveloper'

open_pr_response = requests.get(f"{GITHUB_API_URL}/repos/{repo_name}/pulls?state=open", headers=headers)
open_prs = open_pr_response.json()
num_open_prs = len(open_prs)
print(f"Кол-во открытых пулл реквестов в репозитории {repo_name}: {num_open_prs}")

closed_pr_response = requests.get(f"{GITHUB_API_URL}/repos/{repo_name}/pulls?state=closed", headers=headers)
closed_prs = closed_pr_response.json()
num_closed_prs = len(closed_prs)
print(f"Кол-во закрытых пулл реквестов в репозитории {repo_name}: {num_closed_prs}")
# Out:
# Кол-во открытых пулл реквестов в репозитории CountryDeveloper: 3
# Кол-во закрытых пулл реквестов в репозитории CountryDeveloper: 3
